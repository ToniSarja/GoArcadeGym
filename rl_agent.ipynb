# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
import gymnasium as gym
import numpy as np

class GoEnv(gym.Env):
    def __init__(self, size=9):  # Adjust size to 9 for 9x9 board
        super(GoEnv, self).__init__()
        self.size = size
        self.board = np.zeros((size, size), dtype=int)  # Use `int` instead of `np.int`
        self.action_space = gym.spaces.Discrete(size * size)
        self.observation_space = gym.spaces.Box(low=0, high=2, shape=(size, size), dtype=int)  # (9, 9)

    def reset(self, seed=None):
        self.board = np.zeros((self.size, self.size), dtype=int)  # Use `int` instead of `np.int`
        return self.board, {}

    def step(self, action):
        row, col = divmod(action, self.size)
        reward = 0
        terminated = False
        truncated = False
        info = {}

        # Implement game logic to update the board
        # Example:
        # self.board[row, col] = 1 if self.current_player == "black" else 2
        
        # Implement termination and truncation logic
        # terminated = some_condition
        # truncated = some_condition
        
        return self.board, reward, terminated, truncated, info

    def render(self, mode='human'):
        # Optional rendering logic
        pass

# Check environment
env = GoEnv(size=9)
check_env(env)

# Create and train the model
model = PPO('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=100000)

# Save the model
model.save("go_ppo_agent9x9")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1494 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 882      |
# |    iterations           | 2        |
# |    time_elapsed         | 4        |
# |    total_timesteps      | 4096     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.39    |
# |    explained_variance   | nan      |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0        |
# |    n_updates            | 10       |
# |    policy_gradient_loss | 0        |
# ...
